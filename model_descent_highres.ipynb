# %%
#!pip install datasets

# %%
## Please install torch and datasets
import torch
from torchvision.transforms import functional as t
import torch.nn.functional as f
from datasets import load_dataset
import matplotlib.pyplot as plt

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
## Loading our dataset
ds = load_dataset("ylecun/mnist")

# %%
## Data splits

X_train_p = ds["train"]["image"]
Y_train = ds["train"]["label"]
X_test_p = ds["test"]["image"]
Y_test = ds["test"]["label"]

# %%
## PIL to Tensors

X_train = [t.pil_to_tensor(x) for x in X_train_p]
X_test = [t.pil_to_tensor(x) for x in X_test_p]
X_train = torch.stack(X_train).to(device)
X_test = torch.stack(X_test).to(device)
print(X_train.shape, X_test.shape)
# Out:
# torch.Size([60000, 1, 28, 28]) torch.Size([10000, 1, 28, 28])

# %%
## Fixing the shape

X_train = X_train.view(-1, 28, 28)
X_test = X_test.view(-1, 28, 28)
print(X_train.shape, X_test.shape)
# Out:
# torch.Size([60000, 28, 28]) torch.Size([10000, 28, 28])

# %%
## Making labels into tensors

Y_train = torch.tensor(Y_train).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
## Flattening the image as DNN takes flat tensor as input

X_train = X_train.view(-1, 784).float() / 255.0
X_test = X_test.view(-1, 784).float() / 255.0
print(X_train.shape, X_test.shape)
# Out:
# torch.Size([60000, 784]) torch.Size([10000, 784])

# %%
import numpy as np
from numpy.linalg import svd



class Linear():
  def __init__(self, input_dims, output_dims, B=True, last=False):
    self.training = True
    self.W = (torch.randn(input_dims, output_dims) * (5/3) / (input_dims**0.5)).to(device) if not last else (torch.randn(input_dims, output_dims) * (5/3) / (input_dims**0.5) * 0.1).to(device)
    if B: self.B = torch.randn(output_dims).to(device) if not last else (torch.randn(output_dims) * 0.1).to(device)
    else: self.B = torch.tensor([]).to(device)

  def __call__(self, x):
    if not torch.equal(self.B, torch.tensor([]).to(device)): self.result = x@self.W + self.B
    else: self.result = x@self.W
    return self.result

  def parameters(self):
    return [self.W] + [self.B]


class Tanh():
  def __init__(self):
    self.training = True
    return None

  def __call__(self, x):
    self.result = torch.tanh(x)
    return self.result

  def parameters(self):
    return []

class Dropout():
  def __init__(self, batch_size, output_dims, rate=0.9):
    self.training = True
    self.rate = rate
    self.factor = (torch.rand(batch_size, output_dims) < self.rate).int().to(device)
    return None

  def __call__(self, x):
    if self.training: self.result = x * self.factor
    else: self.result = x
    return self.result

  def parameters(self):
    return []


def decomposition(A, k=1):

    # SVD
    U, S, VT = svd(A, full_matrices=False)


    # Truncate to rank-k
    U_k = U[:, :k]                # (784 x k)
    S_k = np.diag(S[:k])          # (k x k)
    VT_k = VT[:k, :]              # (k x 10)

    # Factor A_k = L @ R, where L and R are low-rank factors
    sqrt_S_k = np.sqrt(S_k)       # (k x k)
    L = U_k @ sqrt_S_k            # (784 x k)
    R = sqrt_S_k @ VT_k           # (k x 10)

    L_flat = L.flatten()
    R_flat = R.flatten()
    LR_concat = np.concatenate([L_flat, R_flat])

    return LR_concat

# %%
n1 = 512
n2 = 256
n3 = 512
n4 = 794
batch_size = 1

updater = [
    Linear(7840, n1), Tanh(), Dropout(batch_size, n1),
    #Linear(n1, n2), Tanh(), Dropout(batch_size, n2),
    #Linear(n2, n3), Tanh(), Dropout(batch_size, n3),
   Linear(n1, 7840, last=True),
    
]

predictor = [
    Linear(784, 10, last=True, B=False)
]

updater_params = [p for layer in updater for p in layer.parameters()]
numparams = 0
for p in updater_params:
    p.requires_grad = True
    numparams += p.numel()


predictor_params = [p for layer in predictor for p in layer.parameters()]
for p in predictor_params:
    p.requires_grad = True
print(numparams)
# Out:
# 8036512

# %%
## Training loop for updater and predictor
iters = 4000  
alpha = 0.01

for c in range(iters):
    # Using no grad as grads of P at t-1 essentially serve as an input that don't depend on any weight
    with torch.no_grad():
        if predictor[0].W.grad is None: 
            P_grad_t_1 = torch.zeros((1, 7840)).to(device)
        else: 
            P_grad_t_1 = predictor[0].W.grad.detach().view(1, 7840)
    
    for p in predictor_params:
        if p.grad is not None:
            p.grad.zero_()
        else:
            print("None Predictor Model Grads")


    x_p = P_grad_t_1
    for layer in updater:
        x_p = layer(x_p)
    P_w_update = x_p.view(784, 10)

    P_w_t_1 = predictor[0].W.detach()
    predictor[0].W = P_w_t_1 + P_w_update

    print(predictor[0].W.requires_grad)

    predictions = X_train @ predictor[0].W
    loss = f.cross_entropy(predictions, Y_train)
    loss.backward()

    print(f"Grad for predictor[0].W: {'None' if predictor[0].W.grad is None else 'Exists'}")

    for p in updater_params:
        print(f"Grad for updater param: {'None' if p.grad is None else 'Exists'}")
        p.data -= alpha * p.grad
        p.grad.zero_()

    if c % 20 == 0:
        print(f"Iteration {c:4d}, Loss: {loss.item():.6f}")
# Out:
# /tmp/ipykernel_2307198/704527553.py:8: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at aten/src/ATen/core/TensorBody.h:489.)
#   if predictor[0].W.grad is None:
# /tmp/ipykernel_2307198/704527553.py:14: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at aten/src/ATen/core/TensorBody.h:489.)
#   if p.grad is not None:
# /tmp/ipykernel_2307198/704527553.py:36: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at aten/src/ATen/core/TensorBody.h:489.)
#   print(f"Grad for predictor[0].W: {'None' if predictor[0].W.grad is None else 'Exists'}")
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration    0, Loss: 4.306601
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration   20, Loss: 3.727113
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration   40, Loss: 5.229379
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration   60, Loss: 6.516065
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration   80, Loss: 7.556886
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  100, Loss: 8.253112
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  120, Loss: 9.036468
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  140, Loss: 9.822773
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  160, Loss: 10.467837
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  180, Loss: 11.112778
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  200, Loss: 11.632530
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# ...
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  520, Loss: 16.469887
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  540, Loss: 16.627918
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  560, Loss: 16.725925
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Iteration  580, Loss: 16.907789
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# None Predictor Model Grads
# None Predictor Model Grads
# True
# Grad for predictor[0].W: None
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# Grad for updater param: Exists
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 9
#       7 with torch.no_grad():
#       8     if predictor[0].W.grad is None:
# ----> 9         P_grad_t_1 = torch.zeros((1, 7840)).to(device)
#      10     else:
#      11         P_grad_t_1 = predictor[0].W.grad.detach().view(1, 7840)
#
# KeyboardInterrupt:

# %%
## Training loop for updater and predictor
iters = 4000  
alpha = 0.01

for c in range(iters):
    # Using no grad as grads of P at t-1 essentially serve as an input that don't depend on any weight
    with torch.no_grad():
        if predictor[0].W.grad is None: 
            print("None grad")
            P_grad_t_1 = torch.zeros((1, 7840)).to(device)
        else: 
            print("Normal grad")
            P_grad_t_1 = predictor[0].W.grad.detach().view(1, 7840)
    
    for p in predictor_params:
        if p.grad is not None:
            p.grad.zero_()
        else:
            print("None Loss")


    x_p = P_grad_t_1
    for layer in updater:
        x_p = layer(x_p)
    P_w_update = x_p.view(784, 10)


    # Predictor weights determine final loss. 
    # Predictor weight updates shouldn't depend on weight updates, like in any other neural network?
    P_w_t_1 = predictor[0].W.detach()
    predictor[0].W = P_w_t_1 + P_w_update

    predictions = X_train @ predictor[0].W
    loss = f.cross_entropy(predictions, Y_train)
    loss.backward()

    for p in updater_params:
        p.data -= alpha * p.grad
        p.grad.zero_()


    
    if c % 20 == 0:
        print(f"Iteration {c:4d}, Loss: {loss.item():.6f}")
# Out:
# /tmp/ipykernel_1484612/2688820518.py:8: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at aten/src/ATen/core/TensorBody.h:489.)
#   if predictor[0].W.grad is None:
# None grad
# None Loss
# None Loss
# Iteration    0, Loss: 4.753555
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration   20, Loss: 7.446398
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration   40, Loss: 9.568725
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration   60, Loss: 11.818635
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration   80, Loss: 15.406134
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  100, Loss: 16.539495
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  120, Loss: 16.603178
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  140, Loss: 19.256580
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  160, Loss: 18.525145
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  180, Loss: 20.606684
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  200, Loss: 20.309999
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  220, Loss: 21.679798
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  240, Loss: 21.664991
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  260, Loss: 22.048620
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  280, Loss: 23.076191
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  300, Loss: 22.881273
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  320, Loss: 23.501476
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  340, Loss: 23.734287
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  360, Loss: 24.111797
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  380, Loss: 24.655039
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  400, Loss: 25.072914
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  420, Loss: 24.970263
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  440, Loss: 25.618740
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  460, Loss: 25.869911
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  480, Loss: 25.385607
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  500, Loss: 26.440060
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  520, Loss: 25.927624
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  540, Loss: 26.616608
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  560, Loss: 26.591433
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  580, Loss: 27.022051
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  600, Loss: 26.915373
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  620, Loss: 27.342659
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  640, Loss: 27.175486
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  660, Loss: 27.618523
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  680, Loss: 27.170805
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  700, Loss: 27.580931
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  720, Loss: 27.805349
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  740, Loss: 27.559612
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  760, Loss: 28.185471
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  780, Loss: 28.014328
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  800, Loss: 28.349337
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  820, Loss: 28.474129
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  840, Loss: 28.990454
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  860, Loss: 28.462904
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  880, Loss: 28.835865
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  900, Loss: 29.171026
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  920, Loss: 28.472700
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  940, Loss: 29.061716
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  960, Loss: 29.321915
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration  980, Loss: 28.831581
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1000, Loss: 29.059641
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1020, Loss: 29.423355
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1040, Loss: 28.961487
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1060, Loss: 28.875679
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1080, Loss: 29.774134
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1100, Loss: 29.275677
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1120, Loss: 29.455278
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1140, Loss: 29.951180
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1160, Loss: 29.367420
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1180, Loss: 29.191462
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1200, Loss: 29.701044
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1220, Loss: 29.658270
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1240, Loss: 29.294003
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1260, Loss: 30.133854
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1280, Loss: 29.806063
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1300, Loss: 29.726034
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# None grad
# None Loss
# None Loss
# Iteration 1320, Loss: 30.422890
# None grad
# None Loss
# None Loss
# None grad
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       8 if predictor[0].W.grad is None:
#       9     print("None grad")
# ---> 10     P_grad_t_1 = torch.zeros((1, 7840)).to(device)
#      11 else:
#      12     print("Normal grad")
#
# KeyboardInterrupt:

# %%
# ## Training loop for updater and predictor
# iters = 4000  
# alpha = 0.01

# for c in range(iters):
#     # Zero updater gradients
#     for p in updater_params:
#         if p.grad is not None:
#             p.grad.zero_()

#     # Get predictor grads
#     with torch.no_grad():
#         if predictor[0].W.grad != None: 
#             print("Normal update")
#             with torch.no_grad():
#                 P_grad_copy = predictor[0].W.grad.detach().flatten().unsqueeze(0)
#         else:
#             print("None update")
#             P_grad_copy = torch.zeros((1, 7840)).to(device)
    

#     # Zero predictor gradients
#     for p in predictor_params:
#         if p.grad is not None:
#             p.grad.zero_()


#     updater_output = P_grad_copy
#     for layer in updater:
#         updater_output = layer(updater_output)
    
#     W_update = updater_output.view((784, 10)) * 0.1
    
#     predictor[0].W.data =  predictor[0].W.data + W_update.data
#     predictions = X_train @ predictor[0].W
#     loss = f.cross_entropy(predictions, Y_train)
#     torch.autograd.set_detect_anomaly(True)
#     # Backward and update
#     loss.backward()
#     for p in updater_params:
#         if p.grad is not None:
#             p.data -= alpha * p.grad

#     if c % 20 == 0:
#         print(f"Iteration {c:4d}, Loss: {loss.item():.6f}")
# Out:
# None update
# Iteration    0, Loss: 2.301098
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration   20, Loss: 5.443576
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration   40, Loss: 9.989386
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration   60, Loss: 14.686119
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration   80, Loss: 19.421894
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  100, Loss: 24.173096
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  120, Loss: 28.931906
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  140, Loss: 33.695026
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  160, Loss: 38.460815
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  180, Loss: 43.228371
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  200, Loss: 47.997181
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  220, Loss: 52.766876
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  240, Loss: 57.537247
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  260, Loss: 62.308147
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  280, Loss: 67.079407
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  300, Loss: 71.851028
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  320, Loss: 76.622887
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  340, Loss: 81.394974
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  360, Loss: 86.167206
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  380, Loss: 90.939613
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  400, Loss: 95.712143
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  420, Loss: 100.484795
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  440, Loss: 105.257515
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  460, Loss: 110.030334
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  480, Loss: 114.803215
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  500, Loss: 119.576149
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  520, Loss: 124.349182
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  540, Loss: 129.122192
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  560, Loss: 133.895309
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  580, Loss: 138.668442
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  600, Loss: 143.441650
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  620, Loss: 148.214828
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  640, Loss: 152.988083
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  660, Loss: 157.761353
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  680, Loss: 162.534714
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  700, Loss: 167.308029
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  720, Loss: 172.081345
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  740, Loss: 176.854736
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  760, Loss: 181.628174
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  780, Loss: 186.401566
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  800, Loss: 191.174957
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  820, Loss: 195.948395
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  840, Loss: 200.721802
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  860, Loss: 205.495285
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  880, Loss: 210.268753
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  900, Loss: 215.042160
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  920, Loss: 219.815643
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  940, Loss: 224.589127
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  960, Loss: 229.362656
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration  980, Loss: 234.136154
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1000, Loss: 238.909653
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1020, Loss: 243.683121
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1040, Loss: 248.456650
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1060, Loss: 253.230179
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1080, Loss: 258.003784
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1100, Loss: 262.777344
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1120, Loss: 267.550751
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1140, Loss: 272.324463
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1160, Loss: 277.097961
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1180, Loss: 281.871552
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1200, Loss: 286.645111
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1220, Loss: 291.418732
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1240, Loss: 296.192352
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1260, Loss: 300.965942
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1280, Loss: 305.739502
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Iteration 1300, Loss: 310.513153
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# Normal update
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 39
#      37 torch.autograd.set_detect_anomaly(True)
#      38 # Backward and update
# ---> 39 loss.backward()
#      40 for p in updater_params:
#      41     if p.grad is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# ## Training
# iters = 4000
# alpha = 0.01

# for c in range(iters):
#     ## Forward Pass through predictor
#     for layer in predictor:
#       layer.training = False
#     x = X_train
#     print(x.shape)
#     for layer in predictor:
#       x = layer(x)
#     # Loss
#     Loss = f.cross_entropy(x, Y_train)


#     ## Forward Pass through updater
#     for layer in layers:
#       layer.training = True

#     # Full SVD
#     A = predictor[0].W.detach().cpu().numpy()  # 784 x 10
#     LR_concat = decomposition(A, k=1) # 794
#     print("LR_concat shape:", LR_concat.shape)

#     i = torch.stack([torch.tensor(LR_concat).to(device)])
#     print(i.shape)

#     for layer in layers:
#       i = layer(i)
#     print(i.shape)
    
#     L_update = i[:, :784].reshape(784, 1)
#     R_update = i[:, 784:].reshape(1, 10)
#     predictor_W_update = L_update @ R_update


#     ## Weight update for predicter
#     predictor[0].W+=predictor_W_update


#     # Calculating Gradient for updater model
#     for layer in layers:
#       layer.result.retain_grad() # This stores grad of layers like Tanh that have no params to update

#     for p in params:
#         p.grad = None

#     Loss.backward()

#     # Weight Update for updater model
#     for p in params:
#         p.data += -alpha * p.grad



#     if c % (iters/20) == 0:
#         print(Loss)

# %%
def accuracy(X, Y, layersv=predictor):
    for layer in layersv:
      layer.training=False
    # Forward
    x = X
    for layer in layersv:
      x = layer(x)
    probs = f.softmax(x, 1)
    answers = x.argmax(1)
    c = 0
    for a, y in zip(answers, Y):
        if a==y: c+=1
    return c / answers.shape[0] * 100

def loss(X, Y, layersv = predictor):
    x = X
    for layer in layersv:
      x = layer(x)
    return f.cross_entropy(x, Y)

print(f"train accuracy: {accuracy(X_train, Y_train)} | test accuracy: {accuracy(X_test, Y_test)}")
print(f"train loss: {loss(X_train, Y_train)} | test loss: {loss(X_test, Y_test)}")
# Out:
# train accuracy: 76.36833333333334 | test accuracy: 77.13
# train loss: 1.5593186616897583 | test loss: 1.4697450399398804
